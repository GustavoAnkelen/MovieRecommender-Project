# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
path = r'data_movies\TMDB_all_movies.csv'

# %%
data_movies = pd.read_csv(path)

# %%
data_movies.head()
# Out:
#    id                             title  vote_average  vote_count    status  \
# 0   2                             Ariel         7.100       340.0  Released
# 1   3               Shadows in Paradise         7.300       403.0  Released
# 2   5                        Four Rooms         5.858      2672.0  Released
# 3   6                    Judgment Night         6.500       333.0  Released
# 4   8  Life in Loops (A Megacities RMX)         7.500        27.0  Released
#
#   release_date     revenue  runtime      budget    imdb_id  ...  \
# 0   1988-10-21         0.0     73.0         0.0  tt0094675  ...
# 1   1986-10-17         0.0     74.0         0.0  tt0092149  ...
# 2   1995-12-09   4257354.0     98.0   4000000.0  tt0113101  ...
# 3   1993-10-15  12136938.0    109.0  21000000.0  tt0107286  ...
# 4   2006-01-01         0.0     80.0     42000.0  tt0825671  ...
#
#                          spoken_languages  \
# 0                                   suomi
# ...

# %%
data_movies.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'budget', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'cast', 'director', 'director_of_photography', 'writers', 'producers',
#        'music_composer', 'imdb_rating', 'imdb_votes', 'poster_path'],
#       dtype='object')

# %%
### Here we select some relevant columns for our study

features = ['title','imdb_id','overview','cast', 'director', 'vote_average','vote_count', 'imdb_rating','imdb_votes']
df_features = data_movies[features]

# %%
df_features
# Out:
#                                     title    imdb_id  \
# 0                                   Ariel  tt0094675
# 1                     Shadows in Paradise  tt0092149
# 2                              Four Rooms  tt0113101
# 3                          Judgment Night  tt0107286
# 4        Life in Loops (A Megacities RMX)  tt0825671
# ...                                   ...        ...
# 1063329                             Žatva        NaN
# 1063330                 Resurrection Fern        NaN
# 1063331                   Earth Tone Grid        NaN
# 1063332                               NaN        NaN
# 1063333                               NaN        NaN
#
#                                                   overview  \
# 0        A Finnish man goes to the city to find a job a...
# 1        Nikander, a rubbish collector and would-be ent...
# 2        It's Ted the Bellhop's first night on the job....
# 3        Four young friends, while taking a shortcut en...
# ...

# %%
clean_df_features1 = df_features.dropna()
clean_df_features1
# Out:
#                                                      title    imdb_id  \
# 0                                                    Ariel  tt0094675
# 1                                      Shadows in Paradise  tt0092149
# 2                                               Four Rooms  tt0113101
# 3                                           Judgment Night  tt0107286
# 6                                                Star Wars  tt0076759
# ...                                                    ...        ...
# 1062993                                          Intimisto  tt0309718
# 1062996                                 night hunters 2025  tt0794986
# 1063031  Rosina Fumo viene in città... per farsi il cor...  tt0186501
# 1063088                                            Intezar  tt0233948
# 1063153                       Under the Whistle of Bullets  tt0237576
#
#                                                   overview  \
# 0        A Finnish man goes to the city to find a job a...
# ...

# %%
clean_df_features1.to_csv('data_movies.csv', index=False)
